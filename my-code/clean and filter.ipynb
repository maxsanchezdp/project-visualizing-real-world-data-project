# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import pprint
import re
import requests as req

client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %% [markdown]
# PyMongo query to keep only companies with office longitude and latitude information available:

# %%
query={'$and': [{"offices.latitude":{'$not':{'$eq':None}}},{"offices.longitude":{'$not':{'$eq':None}}},{"offices.latitude":{'$exists':True}},{"offices.longitude":{'$exists':True}}]}
projection={'_id':0,'category_code':1,'name':1,'number_of_employees':1,'founded_year':1,'deadpooled_year':1,'tag_list':1,'description':1,'total_money_raised':1,"offices.latitude":1,"offices.longitude":1}
with_geoloc=db.companies.find(query,projection)

# %% [markdown]
# Make a dataframe from the previous query:

# %%
df=pd.DataFrame(with_geoloc)

# %% [markdown]
# Re-order columns:

# %%
df=df[['name','category_code','description','founded_year','deadpooled_year','number_of_employees','total_money_raised','tag_list','offices']]
df.head(3)
# Out:
#         name category_code                  description  founded_year  \
# 0  AdventNet    enterprise   Server Management Software        1996.0
# 1   Wetpaint           web  Technology Platform Company        2005.0
# 2       Zoho      software   Online Business Apps Suite        2005.0
#
#    deadpooled_year  number_of_employees total_money_raised  \
# 0              2.0                600.0                 $0
# 1              1.0                 47.0             $39.8M
# 2              3.0               1600.0                 $0
#
#                                             tag_list  \
# 0
# 1  wiki, seattle, elowitz, media-industry, media-...
# 2  zoho, officesuite, spreadsheet, writer, projec...
#
#                                              offices
# 0  [{'latitude': 37.692934, 'longitude': -121.904...
# 1  [{'latitude': 47.603122, 'longitude': -122.333...
# 2  [{'latitude': 37.692934, 'longitude': -121.904...

# %% [markdown]
# Get exchange rate from API to "clean" currency:

# %%
url="https://api.exchangeratesapi.io/latest"
query_params={"base":"USD","symbols":["CAD","EUR","GBP","SEK"]}

res = req.get(url,params=query_params)
content=res.json()
rates=content["rates"]

rates
# Out:
# {'CAD': 1.3124497992,
#  'EUR': 0.8924587238,
#  'GBP': 0.8029897367,
#  'SEK': 9.490227577}

# %%
def money_dollars(s):
    mfloat=float(re.search("(\d*\.\d*|\d+)",s).group(1))
    if s.endswith("M"): mfloat*=1000000
    if s.endswith("B"): mfloat*=1000000000
    if s.endswith("k"): mfloat*=1000
    if s.startswith("C$"): mfloat*=1/rates["CAD"]
    if s.startswith("€"): mfloat*=1/rates["EUR"]
    if s.startswith("£"): mfloat*=1/rates["GBP"]
    if s.startswith("kr"): mfloat*=1/rates["SEK"]
    return round(mfloat)

df["raised_money_dollars"]=df.copy()["total_money_raised"].apply(money_dollars)
df=df[['name','category_code','description','founded_year','deadpooled_year','number_of_employees','total_money_raised',"raised_money_dollars",'tag_list','offices']]
df.reset_index(inplace=True)
df.head(3)
# Out:
#    index       name category_code                  description  founded_year  \
# 0      0  AdventNet    enterprise   Server Management Software        1996.0
# 1      1   Wetpaint           web  Technology Platform Company        2005.0
# 2      2       Zoho      software   Online Business Apps Suite        2005.0
#
#    deadpooled_year  number_of_employees total_money_raised  \
# 0              2.0                600.0                 $0
# 1              1.0                 47.0             $39.8M
# 2              3.0               1600.0                 $0
#
#    raised_money_dollars                                           tag_list  \
# 0                     0
# 1              39800000  wiki, seattle, elowitz, media-industry, media-...
# 2                     0  zoho, officesuite, spreadsheet, writer, projec...
#
#                                              offices
# 0  [{'latitude': 37.692934, 'longitude': -121.904...
# 1  [{'latitude': 47.603122, 'longitude': -122.333...
# 2  [{'latitude': 37.692934, 'longitude': -121.904...

# %%
offices_list=df.copy()[["index","offices"]]
offices_list_clean= pd.DataFrame(offices_list["offices"].tolist()).stack().reset_index(level=1, drop=True).reset_index(name='offices')

display(offices_list_clean.head(3))
# Out:
#    index                                            offices
# 0      0  {'latitude': 37.692934, 'longitude': -121.904945}
# 1      1  {'latitude': 47.603122, 'longitude': -122.333253}
# 2      1  {'latitude': 40.7237306, 'longitude': -73.9964...

# %%
df_offices=df.merge(offices_list_clean,left_on='index', right_on='index')
df_offices.head(3)
# Out:
#    index       name category_code                  description  founded_year  \
# 0      0  AdventNet    enterprise   Server Management Software        1996.0
# 1      1   Wetpaint           web  Technology Platform Company        2005.0
# 2      1   Wetpaint           web  Technology Platform Company        2005.0
#
#    deadpooled_year  number_of_employees total_money_raised  \
# 0              2.0                600.0                 $0
# 1              1.0                 47.0             $39.8M
# 2              1.0                 47.0             $39.8M
#
#    raised_money_dollars                                           tag_list  \
# 0                     0
# 1              39800000  wiki, seattle, elowitz, media-industry, media-...
# 2              39800000  wiki, seattle, elowitz, media-industry, media-...
#
#                                            offices_x  \
# 0  [{'latitude': 37.692934, 'longitude': -121.904...
# 1  [{'latitude': 47.603122, 'longitude': -122.333...
# 2  [{'latitude': 47.603122, 'longitude': -122.333...
#
#                                            offices_y
# 0  {'latitude': 37.692934, 'longitude': -121.904945}
# 1  {'latitude': 47.603122, 'longitude': -122.333253}
# 2  {'latitude': 40.7237306, 'longitude': -73.9964...

# %%
df_offices = df_offices.drop(["offices_x"], axis=1)
df_offices.rename(index=str, columns={"offices_y": "offices"},inplace=True)
df_offices.head(3)
# Out:
#    index       name category_code                  description  founded_year  \
# 0      0  AdventNet    enterprise   Server Management Software        1996.0
# 1      1   Wetpaint           web  Technology Platform Company        2005.0
# 2      1   Wetpaint           web  Technology Platform Company        2005.0
#
#    deadpooled_year  number_of_employees total_money_raised  \
# 0              2.0                600.0                 $0
# 1              1.0                 47.0             $39.8M
# 2              1.0                 47.0             $39.8M
#
#    raised_money_dollars                                           tag_list  \
# 0                     0
# 1              39800000  wiki, seattle, elowitz, media-industry, media-...
# 2              39800000  wiki, seattle, elowitz, media-industry, media-...
#
#                                              offices
# 0  {'latitude': 37.692934, 'longitude': -121.904945}
# 1  {'latitude': 47.603122, 'longitude': -122.333253}
# 2  {'latitude': 40.7237306, 'longitude': -73.9964...

# %%
def get_coords(data):
    data = data['offices']
#    return (len(data),data[0]['latitude'],data[0]['longitude'])

    # Only create the geoJSON object if all geodata is available
    principal = None
    if data['latitude'] and data['longitude']:
        principal = {
            "type":"Point",
            "coordinates":[data['longitude'], data['latitude']]
        }

    return {
        "lat": data['latitude'],
        "lng": data['longitude'],
        "geo_point": principal
    }


offices = df_offices[["offices"]].apply(get_coords, result_type="expand", axis=1)

# %%
df_geo=pd.concat([df_offices,offices], axis=1)
df_geo = df_geo.drop(["offices"], axis=1)

# %%
df_geo["category_code"]=df_geo["category_code"].fillna("None")
df_geo["description"]=df_geo["description"].fillna("None")
df_geo["description"]=df_geo["description"].fillna("None")
df_geo["tag_list"]=df_geo["tag_list"].fillna("None")
df_geo["founded_year"]=df_geo["founded_year"].fillna(0)
df_geo["deadpooled_year"]=df_geo["deadpooled_year"].fillna(0)
df_geo["number_of_employees"]=df_geo["number_of_employees"].fillna(0)
df_geo.isnull().sum()
# Out:
# index                   0
# name                    0
# category_code           0
# description             0
# founded_year            0
# deadpooled_year         0
# number_of_employees     0
# total_money_raised      0
# raised_money_dollars    0
# tag_list                0
# geo_point               0
# lat                     0
# lng                     0
# dtype: int64

# %%
df_geo["founded_year"]=df_geo["founded_year"].astype('int')
df_geo["deadpooled_year"]=df_geo["deadpooled_year"].astype('int')
df_geo["number_of_employees"]=df_geo["number_of_employees"].astype('int')
df_geo.dtypes
# Out:
# index                     int64
# name                     object
# category_code            object
# description              object
# founded_year              int64
# deadpooled_year           int64
# number_of_employees       int64
# total_money_raised       object
# raised_money_dollars      int64
# tag_list                 object
# geo_point                object
# lat                     float64
# lng                     float64
# dtype: object

# %%
df_geo = df_geo.drop(["total_money_raised"], axis=1)

# %%
df_geo
# Out:
#       index                            name     category_code  \
# 0         0                       AdventNet        enterprise
# 1         1                        Wetpaint               web
# 2         1                        Wetpaint               web
# 3         2                            Zoho          software
# 4         3                            Digg              news
# 5         4                         Flektor       games_video
# 6         5                         Postini               web
# 7         6                            Geni               web
# 8         7           Fox Interactive Media               web
# 9         8                          Gizmoz               web
# 10        9                          Scribd              news
# 11       10                            Lala       games_video
# 12       11                           Helio            mobile
# 13       12                         Slacker             music
# 14       13                         MeetMoi            social
# 15       14                         Twitter            social
# 16       15                             CBS              news
# 17       16                        Facebook            social
# 18       16                        Facebook            social
# 19       16                        Facebook            social
# 20       17                        Babelgum       games_video
# 21       18                          Viacom               web
# 22       19                           Plaxo               web
# 23       20                           Joost       games_video
# 24       21                            eBay               web
# 25       22                      Technorati       advertising
# 26       23                        Powerset            search
# 27       24                         Sparter       games_video
# 28       25                          Mahalo               web
# 29       26                            Kyte       games_video
# ...     ...                             ...               ...
# 9678   8996                Chestnut Medical           biotech
# 9679   8997                 Luminus Devices             other
# 9680   8998                          Nellix              None
# 9681   8999                      Hellocoton             other
# 9682   9000                       Buddhacom            search
# 9683   9001              Emrise Corporation          hardware
# 9684   9002                     Atlantic BT               web
# 9685   9003                      AwardSpace   network_hosting
# 9686   9004                        InstantQ       advertising
# 9687   9005                        SEO Sumo  public_relations
# 9688   9006                        NextLabs        enterprise
# 9689   9007                       acrossair            mobile
# 9690   9008                        Cantimer              None
# 9691   9009                  Cameron Health           medical
# 9692   9010         Celestial Semiconductor     semiconductor
# 9693   9011                       MyChances        consulting
# 9694   9011                       MyChances        consulting
# 9695   9012                        Purfresh         cleantech
# 9696   9013                          Getyoo            mobile
# 9697   9014                 InSound Medical           biotech
# 9698   9015                  Axon Solutions          software
# 9699   9016                         Intergy          software
# 9700   9017                   Willdan Group             other
# 9701   9018  Contemporary Computer Services          software
# 9702   9019                  EnterSys Group          software
# 9703   9020                            QSGI          software
# 9704   9021                          Oriact          software
# 9705   9022                      AfterLogic          software
# 9706   9023             EnteGreat Solutions          software
# 9707   9024                       EnteGreat        enterprise
#
#                                  description  founded_year  deadpooled_year  \
# 0                 Server Management Software          1996                2
# 1                Technology Platform Company          2005                1
# 2                Technology Platform Company          2005                1
# 3                 Online Business Apps Suite          2005                3
# 4         user driven social content website          2004                0
# 5                                       None             0                0
# 6                                       None          1999                0
# 7              Geneology social network site          2006                0
# 8                                                     1979                0
# 9                            Photo animation          2003                0
# 10                      Read Unlimited Books          2007                0
# 11            hub for online music discovery             0                0
# 12           Mobile Virtual Network Operator          2005                0
# 13               Music Personalization Suite          2006                0
# 14                             Mobile Dating          2007                0
# 15          Real time communication platform          2006                0
# 16                                                    1986                0
# 17                            Social network          2004                0
# 18                            Social network          2004                0
# 19                            Social network          2004                0
# 20                                                    2007             2013
# 21                             TV production          1971                0
# 22                        Contact Management          2002                0
# 23                                      None          2006                0
# 24                        Online Marketplace          1995                0
# 25    Advertising platform/Publisher network          2002                0
# 26                                                    2006                0
# 27                                                    2007             2008
# 28                Life long learning content          2007                0
# 29            Online & Mobile Video Platform          2006                0
# ...                                      ...           ...              ...
# 9678                                                     0                0
# 9679                                                  2002                0
# 9680                                                     0                0
# 9681            magazine and blog aggregator          2008                0
# 9682                     SEO company Toronto          2008                0
# 9683                                                     0                0
# 9684             Web Development, Web Design          1998                0
# 9685                    Web Hosting Services          2004                0
# 9686            Last Minute Restaurant Deals          2009                0
# 9687                  Strategic SEO Services          2009                0
# 9688    Information Risk Management Software          2004                0
# 9689                        iPhone app house          2009                0
# 9690                                                  2006                0
# 9691                                                  2001                0
# 9692                                                  2004                0
# 9693          College admissions predictions          2009                0
# 9694          College admissions predictions          2009                0
# 9695                                                  1996                0
# 9696                    NFC Events Solutions          2009                0
# 9697                         Hearing Devices             0                0
# 9698                                                  2004                0
# 9699                                                  2003                0
# 9700                                                     0                0
# 9701                                                  1974                0
# 9702                                                  2000                0
# 9703                                                  1967                0
# 9704      Solutions for software development          2009                0
# 9705       .NET Email Components and Webmail          2002                0
# 9706                                                     0                0
# 9707                                                  2000                0
#
#       number_of_employees  raised_money_dollars  \
# 0                     600                     0
# 1                      47              39800000
# 2                      47              39800000
# 3                    1600                     0
# 4                      60              45000000
# 5                       0                     0
# 6                       0                     0
# 7                      18              16500000
# 8                       0                     0
# 9                       0              18100000
# 10                     50              25800000
# 11                      0              44200000
# 12                      0                     0
# 13                      0              73100000
# 14                     15               5580000
# 15                   1300            1160000000
# 16                      0                     0
# 17                   5299            2430000000
# 18                   5299            2430000000
# 19                   5299            2430000000
# 20                      0              13200000
# 21                      0                     0
# 22                     50              28300000
# 23                      0              45000000
# 24                  15000               6700000
# 25                     35              32100000
# 26                     60              22500000
# 27                      0                     0
# 28                     40              21000000
# 29                     40              23400000
# ...                   ...                   ...
# 9678                    0               7800000
# 9679                    0             136000000
# 9680                    0               6500000
# 9681                    4                     0
# 9682                    8                     0
# 9683                    0                     0
# 9684                   30                     0
# 9685                   35                     0
# 9686                    3                     0
# 9687                    5                     0
# 9688                  100                     0
# 9689                    6                     0
# 9690                    0               2000000
# 9691                    0             121000000
# 9692                    0               2000000
# 9693                    2                     0
# 9694                    2                     0
# 9695                    0              62700000
# 9696                   10               1266165
# 9697                    0              11000000
# 9698                    0                     0
# 9699                    0                     0
# 9700                  385                     0
# 9701                    0                     0
# 9702                    0                     0
# 9703                  164                     0
# 9704                    0                     0
# 9705                    0                     0
# 9706                    0                     0
# 9707                    0                     0
#
#                                                tag_list  \
# 0
# 1     wiki, seattle, elowitz, media-industry, media-...
# 2     wiki, seattle, elowitz, media-industry, media-...
# 3     zoho, officesuite, spreadsheet, writer, projec...
# 4     community, social, news, bookmark, digg, techn...
# 5                                 flektor, photo, video
# 6
# 7            geni, geneology, social, family, genealogy
# 8
# 9                    avatar, widget, 3d, facial, taylor
# 10    book-subscription, digital-library, netflix-fo...
# 11
# 12                                  mobile, helio, mvno
# 13
# 14            mobile, dating, location, realtime, phone
# 15    text, messaging, social, community, twitter, t...
# 16                                                 None
# 17    facebook, college, students, profiles, network...
# 18    facebook, college, students, profiles, network...
# 19    facebook, college, students, profiles, network...
# 20                                    iptv, web2ireland
# 21                                                 None
# 22    contact-management, address-book, sync, contac...
# 23    iptv, babelgum, television, video, thevenicepr...
# 24                         auction, bid, search, market
# 25                                        blogs, search
# 26    searchengine, google, techcrunch40, natural-la...
# 27     gaming, game, wow, worldofwarcraft, virtualgoods
# 28     search, search-engine, human-powered-search, aaa
# 29    video, mobile, iphone-app, video-platform, mob...
# ...                                                 ...
# 9678
# 9679
# 9680
# 9681                            blog, aggregator, women
# 9682                      seo-toronto, seo, seo-company
# 9683
# 9684  web-development, web-design, internet-marketin...
# 9685  free-webhosting, webhosting, vps, dedicated-se...
# 9686
# 9687  miami-seo, miami-seo-company, miami-seo-specia...
# 9688
# 9689                   iphone, games, augmented-reality
# 9690
# 9691
# 9692
# 9693  college, college-admissions, predictions, stat...
# 9694  college, college-admissions, predictions, stat...
# 9695
# 9696  social-networks, networking, web, real-life, w...
# 9697
# 9698
# 9699
# 9700
# 9701
# 9702
# 9703
# 9704  collaboration, communication, appliance, softw...
# 9705
# 9706
# 9707                                               None
#
#                                               geo_point        lat         lng
# 0     {'type': 'Point', 'coordinates': [-121.904945,...  37.692934 -121.904945
# 1     {'type': 'Point', 'coordinates': [-122.333253,...  47.603122 -122.333253
# 2     {'type': 'Point', 'coordinates': [-73.9964312,...  40.723731  -73.996431
# 3     {'type': 'Point', 'coordinates': [-121.904945,...  37.692934 -121.904945
# 4     {'type': 'Point', 'coordinates': [-122.394523,...  37.764726 -122.394523
# 5     {'type': 'Point', 'coordinates': [-118.379768,...  34.025958 -118.379768
# 6     {'type': 'Point', 'coordinates': [-122.247573,...  37.506885 -122.247573
# 7     {'type': 'Point', 'coordinates': [-118.393064,...  34.090368 -118.393064
# 8     {'type': 'Point', 'coordinates': [-118.39417, ...  34.076179 -118.394170
# 9     {'type': 'Point', 'coordinates': [-122.169472,...  37.484130 -122.169472
# 10    {'type': 'Point', 'coordinates': [-122.404052,...  37.789634 -122.404052
# 11    {'type': 'Point', 'coordinates': [-122.154369,...  37.451151 -122.154369
# 12    {'type': 'Point', 'coordinates': [-118.446596,...  34.057498 -118.446596
# 13    {'type': 'Point', 'coordinates': [-117.081406,...  33.022176 -117.081406
# 14    {'type': 'Point', 'coordinates': [-73.985506, ...  40.757929  -73.985506
# 15    {'type': 'Point', 'coordinates': [-122.4169244...  37.776805 -122.416924
# 16    {'type': 'Point', 'coordinates': [-119.306607,...  37.269175 -119.306607
# 17    {'type': 'Point', 'coordinates': [-122.151801,...  37.416050 -122.151801
# 18    {'type': 'Point', 'coordinates': [-6.267494, 5...  53.344104   -6.267494
# 19    {'type': 'Point', 'coordinates': [-73.9792469,...  40.755716  -73.979247
# 20    {'type': 'Point', 'coordinates': [-6.267494, 5...  53.344104   -6.267494
# 21    {'type': 'Point', 'coordinates': [-73.986011, ...  40.757725  -73.986011
# 22    {'type': 'Point', 'coordinates': [-122.055197,...  37.387845 -122.055197
# 23    {'type': 'Point', 'coordinates': [-74.0094471,...  40.746497  -74.009447
# 24    {'type': 'Point', 'coordinates': [-121.930035,...  37.295005 -121.930035
# 25    {'type': 'Point', 'coordinates': [-122.393041,...  37.779558 -122.393041
# 26    {'type': 'Point', 'coordinates': [-122.395289,...  37.778613 -122.395289
# 27    {'type': 'Point', 'coordinates': [-95.712891, ...  37.090240  -95.712891
# 28    {'type': 'Point', 'coordinates': [-118.487267,...  34.017606 -118.487267
# 29    {'type': 'Point', 'coordinates': [-122.409173,...  37.788482 -122.409173
# ...                                                 ...        ...         ...
# 9678  {'type': 'Point', 'coordinates': [-122.1717587...  37.481946 -122.171759
# 9679  {'type': 'Point', 'coordinates': [-71.278022, ...  42.528635  -71.278022
# 9680  {'type': 'Point', 'coordinates': [-122.1161779...  37.449972 -122.116178
# 9681  {'type': 'Point', 'coordinates': [2.3389864, 4...  48.831850    2.338986
# 9682  {'type': 'Point', 'coordinates': [-79.4008589,...  43.676252  -79.400859
# 9683  {'type': 'Point', 'coordinates': [-74.069035, ...  40.270986  -74.069035
# 9684  {'type': 'Point', 'coordinates': [-78.6806784,...  35.896906  -78.680678
# 9685  {'type': 'Point', 'coordinates': [10.1665152, ...  54.323738   10.166515
# 9686  {'type': 'Point', 'coordinates': [-122.036849,...  37.369195 -122.036849
# 9687  {'type': 'Point', 'coordinates': [-80.306331, ...  25.723408  -80.306331
# 9688  {'type': 'Point', 'coordinates': [-122.301534,...  37.553121 -122.301534
# 9689  {'type': 'Point', 'coordinates': [-0.1165365, ...  51.517742   -0.116537
# 9690  {'type': 'Point', 'coordinates': [-122.181753,...  37.484616 -122.181753
# 9691  {'type': 'Point', 'coordinates': [-117.607717,...  33.448010 -117.607717
# 9692  {'type': 'Point', 'coordinates': [-121.92917, ...  37.386417 -121.929170
# 9693  {'type': 'Point', 'coordinates': [-119.8120795...  39.394564 -119.812079
# 9694  {'type': 'Point', 'coordinates': [-122.1802812...  37.448491 -122.180281
# 9695  {'type': 'Point', 'coordinates': [-122.151599,...  37.477008 -122.151599
# 9696  {'type': 'Point', 'coordinates': [4.3464721, 5...  50.839970    4.346472
# 9697  {'type': 'Point', 'coordinates': [-121.998513,...  37.512038 -121.998513
# 9698  {'type': 'Point', 'coordinates': [-74.033251, ...  40.715887  -74.033251
# 9699  {'type': 'Point', 'coordinates': [-121.9366984...  37.701940 -121.936698
# 9700  {'type': 'Point', 'coordinates': [-117.882314,...  33.806525 -117.882314
# 9701  {'type': 'Point', 'coordinates': [-73.08814, 4...  40.775055  -73.088140
# 9702  {'type': 'Point', 'coordinates': [-95.5045451,...  29.848779  -95.504545
# 9703  {'type': 'Point', 'coordinates': [-80.041395, ...  26.705331  -80.041395
# 9704  {'type': 'Point', 'coordinates': [8.4371634, 4...  47.088219    8.437163
# 9705  {'type': 'Point', 'coordinates': [-74.3235539,...  40.793024  -74.323554
# 9706  {'type': 'Point', 'coordinates': [-86.816068, ...  33.518885  -86.816068
# 9707  {'type': 'Point', 'coordinates': [-86.7613019,...  33.407786  -86.761302
#
# [9708 rows x 12 columns]
